# %%
using Distributions

# %%
V_exact(a, b, r) = 16a^2*b^2 - 16π*a*b*r^2 + (64/3)*(a+b)*r^3 - 8r^4
# Out:
# V_exact (generic function with 1 method)

# %%
function MC_volume(a, b, r, N=1000000)
    
    valid = 0
    
    for n in 1:N
        x1, x2 = rand(Uniform(-a, a), 2)
        y1, y2 = rand(Uniform(-b, b), 2)
        
        if (x1-x2)^2 + (y1-y2)^2 >= (2r)^2
                
                valid += 1
        end
    end
    
    return 16a^2 * b^2 * (valid / N)
end
# Out:
# MC_volume (generic function with 2 methods)

# %%
function MC_horiz_hop_area(a, b, r, N=1000000)
    
    eps = 0.01
    
    valid = 0
    
    for n in 1:N
        x1, x2 = rand(Uniform(-a, a), 2)
        y1, y2 = rand(Uniform(-b, b), 2)
        
        if (x1-x2)^2 + (y1-y2)^2 >= (2r)^2 && abs(x1 - x2) < eps
            valid += 1
        end
    end
    
    return (16a^2 * b^2 * (valid / N)) / (2eps)
end
# Out:
# MC_horiz_hop_area (generic function with 2 methods)

# %%
a, b = 0.5, 0.5

num_V_data = Float64[]
exact_V_data = Float64[]

rs = 0.01:0.01:0.24
for r in rs
    @show r
    push!(num_V_data, MC_volume(a, b, r))
    push!(exact_V_data, V_exact(a, b, r))
end
# Out:
# r = 0.01
# r = 0.02
# r = 0.03
# r = 0.04
# r = 0.05
# r = 0.06
# r = 0.07
# r = 0.08
# r = 0.09
# r = 0.1
# r = 0.11
# r = 0.12
# r = 0.13
# r = 0.14
# r = 0.15
# r = 0.16
# r = 0.17
# r = 0.18
# r = 0.19
# r = 0.2
# r = 0.21
# r = 0.22
# r = 0.23
# r = 0.24

# %%
using Plots; gr()
# Out:
# Plots.GRBackend()

# %%
scatter(rs, num_V_data, m=:square, lab="numerical")
plot!(rs, exact_V_data, lab="exact")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip3100)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip3100)" points="
# 32.2221,375.813 580.315,375.813 580.315,11.811 32.2221,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="32" y="11" width="549" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip3102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   137.659,370.353 137.659,17.2711
#   "/>
# <polyline clip-path="url(#clip3102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   250.065,370.353 250.065,17.2711
#   "/>
# <polyline clip-path="url(#clip3102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   362.472,370.353 362.472,17.2711
#   "/>
# <polyline clip-path="url(#clip3102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   474.878,370.353 474.878,17.2711
#   "/>
# <polyline clip-path="url(#clip3102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.4435,323.591 572.094,323.591
#   "/>
# <polyline clip-path="url(#clip3102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.4435,247.995 572.094,247.995
#   "/>
# <polyline clip-path="url(#clip3102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.4435,172.398 572.094,172.398
#   "/>
# <polyline clip-path="url(#clip3102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.4435,96.8021 572.094,96.8021
#   "/>
# <polyline clip-path="url(#clip3102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.4435,21.2058 572.094,21.2058
#   "/>
# <polyline clip-path="url(#clip3100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip3100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,375.813 32.2221,11.811
#   "/>
# <polyline clip-path="url(#clip3100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   137.659,375.813 137.659,370.353
#   "/>
# <polyline clip-path="url(#clip3100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   250.065,375.813 250.065,370.353
#   "/>
# <polyline clip-path="url(#clip3100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   362.472,375.813 362.472,370.353
#   "/>
# <polyline clip-path="url(#clip3100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   474.878,375.813 474.878,370.353
#   "/>
# <polyline clip-path="url(#clip3100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,323.591 40.4435,323.591
#   "/>
# <polyline clip-path="url(#clip3100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,247.995 40.4435,247.995
#   "/>
# <polyline clip-path="url(#clip3100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,172.398 40.4435,172.398
#   "/>
# <polyline clip-path="url(#clip3100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,96.8021 40.4435,96.8021
#   "/>
# <polyline clip-path="url(#clip3100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,21.2058 40.4435,21.2058
#   "/>
# <g clip-path="url(#clip3100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 137.659, 389.613)" x="137.659" y="389.613">0.05</text>
# </g>
# <g clip-path="url(#clip3100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 250.065, 389.613)" x="250.065" y="389.613">0.10</text>
# </g>
# <g clip-path="url(#clip3100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 362.472, 389.613)" x="362.472" y="389.613">0.15</text>
# </g>
# <g clip-path="url(#clip3100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 474.878, 389.613)" x="474.878" y="389.613">0.20</text>
# </g>
# <g clip-path="url(#clip3100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 328.091)" x="26.2221" y="328.091">0.6</text>
# </g>
# <g clip-path="url(#clip3100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 252.495)" x="26.2221" y="252.495">0.7</text>
# </g>
# <g clip-path="url(#clip3100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 176.898)" x="26.2221" y="176.898">0.8</text>
# </g>
# <g clip-path="url(#clip3100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 101.302)" x="26.2221" y="101.302">0.9</text>
# </g>
# <g clip-path="url(#clip3100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 25.7058)" x="26.2221" y="25.7058">1.0</text>
# </g>
# <polygon clip-path="url(#clip3102)" style="fill:#000000; fill-opacity:1" points="
#   42.7342,17.113 42.7342,27.113 52.7342,27.113 52.7342,17.113 42.7342,17.113
#   "/>
# <polygon clip-path="url(#clip3102)" style="fill:#009af9; fill-opacity:1" points="
#   43.7342,18.113 43.7342,26.113 51.7342,26.113 51.7342,18.113 43.7342,18.113
#   "/>
# <polygon clip-path="url(#clip3102)" style="fill:#000000; fill-opacity:1" points="
#   65.2154,19.904 65.2154,29.904 75.2154,29.904 75.2154,19.904 65.2154,19.904
#   "/>
# <polygon clip-path="url(#clip3102)" style="fill:#009af9; fill-opacity:1" points="
#   66.2154,20.904 66.2154,28.904 74.2154,28.904 74.2154,20.904 66.2154,20.904
#   "/>
# <polygon clip-path="url(#clip3102)" style="fill:#000000; fill-opacity:1" points="
#   87.6967,24.2561 87.6967,34.2561 97.6967,34.2561 97.6967,24.2561 87.6967,24.2561
#   "/>
# <polygon clip-path="url(#clip3102)" style="fill:#009af9; fill-opacity:1" points="
#   88.6967,25.2561 88.6967,33.2561 96.6967,33.2561 96.6967,25.2561 88.6967,25.2561
#   "/>
# <polygon clip-path="url(#clip3102)" style="fill:#000000; fill-opacity:1" points="
#   110.178,30.4081 110.178,40.4081 120.178,40.4081 120.178,30.4081 110.178,30.4081
#   "/>
# <polygon clip-path="url(#clip3102)" style="fill:#009af9; fill-opacity:1" points="
#   111.178,31.4081 111.178,39.4081 119.178,39.4081 119.178,31.4081 111.178,31.4081
#   "/>
# <polygon clip-path="url(#clip3102)" style="fill:#000000; fill-opacity:1" points="
#   132.659,37.9201 132.659,47.9201 142.659,47.9201 142.659,37.9201 132.659,37.9201
#   "/>
# <polygon clip-path="url(#clip3102)" style="fill:#009af9; fill-opacity:1" points="
#   133.659,38.9201 133.659,46.9201 141.659,46.9201 141.659,38.9201 133.659,38.9201
#   "/>
# <polygon clip-path="url(#clip3102)" style="fill:#000000; fill-opacity:1" points="
#   155.14,47.1988 155.14,57.1988 165.14,57.1988 165.14,47.1988 155.14,47.1988
#   "/>
# <polygon clip-path="url(#clip3102)" style="fill:#009af9; fill-opacity:1" points="
#   156

# %%
A_horiz_hop_exact(a, b, r) = 16a * (b-r)^2
# Out:
# A_horiz_hop_exact (generic function with 1 method)

# %%
a, b = 0.5, 0.5

num_A_data = Float64[]
exact_A_data = Float64[]

rs = 0.01:0.01:0.24
for r in rs
    @show r
    push!(num_A_data, MC_horiz_hop_area(a, b, r))
    push!(exact_A_data, A_horiz_hop_exact(a, b, r))
end
# Out:
# r = 0.01
# r = 0.02
# r = 0.03
# r = 0.04
# r = 0.05
# r = 0.06
# r = 0.07
# r = 0.08
# r = 0.09
# r = 0.1
# r = 0.11
# r = 0.12
# r = 0.13
# r = 0.14
# r = 0.15
# r = 0.16
# r = 0.17
# r = 0.18
# r = 0.19
# r = 0.2
# r = 0.21
# r = 0.22
# r = 0.23
# r = 0.24

# %%
plot(rs, num_A_data, m=:square, lab="numerical")
plot!(rs, exact_A_data, m=:square, lab="exact")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip3700)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip3700)" points="
# 32.2221,375.813 580.315,375.813 580.315,11.811 32.2221,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="32" y="11" width="549" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip3702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   137.659,370.353 137.659,17.2711
#   "/>
# <polyline clip-path="url(#clip3702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   250.065,370.353 250.065,17.2711
#   "/>
# <polyline clip-path="url(#clip3702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   362.472,370.353 362.472,17.2711
#   "/>
# <polyline clip-path="url(#clip3702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   474.878,370.353 474.878,17.2711
#   "/>
# <polyline clip-path="url(#clip3702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.4435,338.488 572.094,338.488
#   "/>
# <polyline clip-path="url(#clip3702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.4435,296.882 572.094,296.882
#   "/>
# <polyline clip-path="url(#clip3702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.4435,255.275 572.094,255.275
#   "/>
# <polyline clip-path="url(#clip3702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.4435,213.669 572.094,213.669
#   "/>
# <polyline clip-path="url(#clip3702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.4435,172.062 572.094,172.062
#   "/>
# <polyline clip-path="url(#clip3702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.4435,130.456 572.094,130.456
#   "/>
# <polyline clip-path="url(#clip3702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.4435,88.8497 572.094,88.8497
#   "/>
# <polyline clip-path="url(#clip3702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.4435,47.2433 572.094,47.2433
#   "/>
# <polyline clip-path="url(#clip3700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip3700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,375.813 32.2221,11.811
#   "/>
# <polyline clip-path="url(#clip3700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   137.659,375.813 137.659,370.353
#   "/>
# <polyline clip-path="url(#clip3700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   250.065,375.813 250.065,370.353
#   "/>
# <polyline clip-path="url(#clip3700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   362.472,375.813 362.472,370.353
#   "/>
# <polyline clip-path="url(#clip3700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   474.878,375.813 474.878,370.353
#   "/>
# <polyline clip-path="url(#clip3700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,338.488 40.4435,338.488
#   "/>
# <polyline clip-path="url(#clip3700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,296.882 40.4435,296.882
#   "/>
# <polyline clip-path="url(#clip3700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,255.275 40.4435,255.275
#   "/>
# <polyline clip-path="url(#clip3700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,213.669 40.4435,213.669
#   "/>
# <polyline clip-path="url(#clip3700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,172.062 40.4435,172.062
#   "/>
# <polyline clip-path="url(#clip3700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,130.456 40.4435,130.456
#   "/>
# <polyline clip-path="url(#clip3700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,88.8497 40.4435,88.8497
#   "/>
# <polyline clip-path="url(#clip3700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,47.2433 40.4435,47.2433
#   "/>
# <g clip-path="url(#clip3700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 137.659, 389.613)" x="137.659" y="389.613">0.05</text>
# </g>
# <g clip-path="url(#clip3700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 250.065, 389.613)" x="250.065" y="389.613">0.10</text>
# </g>
# <g clip-path="url(#clip3700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 362.472, 389.613)" x="362.472" y="389.613">0.15</text>
# </g>
# <g clip-path="url(#clip3700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 474.878, 389.613)" x="474.878" y="389.613">0.20</text>
# </g>
# <g clip-path="url(#clip3700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 342.988)" x="26.2221" y="342.988">0.4</text>
# </g>
# <g clip-path="url(#clip3700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 301.382)" x="26.2221" y="301.382">0.6</text>
# </g>
# <g clip-path="url(#clip3700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 259.775)" x="26.2221" y="259.775">0.8</text>
# </g>
# <g clip-path="url(#clip3700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 218.169)" x="26.2221" y="218.169">1.0</text>
# </g>
# <g clip-path="url(#clip3700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 176.562)" x="26.2221" y="176.562">1.2</text>
# </g>
# <g clip-path="url(#clip3700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 134.956)" x="26.2221" y="134.956">1.4</text>
# </g>
# <g clip-path="url(#clip3700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 93.3497)" x="26.2221" y="93.3497">1.6</text>
# </g>
# <g clip-path="url(#clip3700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 51.7433)" x="26.2221" y="51.7433">1.8</text>
# </g>
# <polyline clip-path="url(#clip3702)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   47.7342,223.082 70.2154,230.353
#   "/>
# <polyline clip-path="url(#clip3702)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   70.2154
