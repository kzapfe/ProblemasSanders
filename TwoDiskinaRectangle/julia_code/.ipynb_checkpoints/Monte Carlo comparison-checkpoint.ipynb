# %%
using Distributions

# %%
cte=3π/2 #E=1/2, -> abs(v^2)=1 as above
rhmax= h/4 #maximal radius in which a horizontal hopp is possible
rvmax= w/4 #maximal radius in which a vertical hopp is possible (any hopp is not posible in our geometry after this)
rmax=  (h+w-√(2*h*w))/2   #maximal possible radius for discs


volBox(a,b)=16*a^2*b^2
volNegfree(a,b,r)=16*π*a*b*r^2-64/3*r^3*(a+b)+8*r^4

expresioncircularvol(a,b,r,θ)=32*r^2*a*b*θ +64/3*r^3*(a*cos(θ)-b*sin(θ)) + 8*r^4*sin(θ)^2

function volNegCircle(a,b,r)
    # This function only has use if r>rhmax
    α=asin(b/r)
    if(r<rvmax)
        β=0
    else
        β=acos(a/r)
    end
    result=expresioncircularvol(a,b,r,α)-expresioncircularvol(a,b,r,β)
    return result
end

vollowertriangle(a,b,r)= 32*a^2*b*sqrt(r^2-a^2)-32/3*a^2*(r^2-a^2+2*b*sqrt(r^2-a^2))+8*a^2*(r^2-a^2)

voluppertriangle(a,b,r)= 32*b^2*a*sqrt(r^2-b^2)-32/3*b^2*(r^2-b^2+2*a*sqrt(r^2-b^2))+8*b^2*(r^2-b^2)


function volNegGeneral(a,b,r)
    if (r<rhmax)
        result=volNegfree(a,b,r)
    elseif (rhmax<=r) && (r<rvmax)
       # println("a=",a," r =" , r, "r^2-a^2 = ", r^2-a^2)
        result=volNegCircle(a,b,r)+voluppertriangle(a,b,r)
    else
        result=volNegCircle(a,b,r)+voluppertriangle(a,b,r)+vollowertriangle(a,b,r)
    end
    return result
end

function vol(a,b,r) 
    result=volBox(a,b)-volNegGeneral(a,b,r)
  #  print(" vol = ", result, " \t ")
    return result
end
# Out:
# vol (generic function with 1 method)

# %%
function MC_volume(a, b, r, N=1000000)
    # Avaiable Volume in configuration space
    valid = 0
    
    for n in 1:N
        x1, x2 = rand(Uniform(-a, a), 2)
        y1, y2 = rand(Uniform(-b, b), 2)
        
        if (x1-x2)^2 + (y1-y2)^2 >= (2r)^2
                
                valid += 1
        end
    end
    
    return 16a^2 * b^2 * (valid / N)
end
# Out:
# MC_volume (generic function with 2 methods)

# %%
function MC_horiz_hop_area(a, b, r, N=1000000)
        
    #Horizontal Hopping Area in q space
    
    eps = 0.01
    
    valid = 0
    
    for n in 1:N
        x1, x2 = rand(Uniform(-a, a), 2)
        y1, y2 = rand(Uniform(-b, b), 2)
        
        if (x1-x2)^2 + (y1-y2)^2 >= (2r)^2 && abs(x1 - x2) < eps*√(2) # Correction for shrewdness
            valid += 1
        end
    end
    
    return (16a^2 * b^2 * (valid / N)) / (2eps)
end
# Out:
# MC_horiz_hop_area (generic function with 2 methods)

# %%
function MC_collition_area(a, b, r, N=1000000)
    
    eps = 0.01
    
    valid = 0
    
    for n in 1:N
        x1, x2 = rand(Uniform(-a, a), 2)
        y1, y2 = rand(Uniform(-b, b), 2)
        
        dist=√((x1-x2)^2 + (y1-y2)^2)
        
        if  0 <(dist-2r) && (dist -2r)< eps * √(2) # Corrected for shrewdness
            valid += 1
        end
    end
    
    return (16a^2 * b^2 * (valid / N)) / (eps)
end
# Out:
# MC_collition_area (generic function with 2 methods)

# %%
function MC_wall_area(a, b, r, N=1000000)
    
    eps = 0.01
    
    valid = 0
    
    for n in 1:N
        x1, x2 = rand(Uniform(-a, a), 2)
        y1, y2 = rand(Uniform(-b, b), 2)
        
        if  (0 <(a-x1) && (a -x1)< eps) && (x1-x2)^2+(y1-y2)^2>(2*r)^2 
            valid += 1
        end
    end
    
    return (16a^2 * b^2 * (valid / N)) / (eps)
end
# Out:
# MC_wall_area (generic function with 2 methods)

# %%
w, h = 1.5, 1.0

num_V_data = Float64[]
exact_V_data = Float64[]

rs = 0.01:0.01:rmax

for r in rs
    
    @show r

    a = w/2 - r
    b = h/2 - r

    push!(num_V_data, MC_volume(a, b, r))
    push!(exact_V_data, vol(a, b, r))
end
# Out:
# r = 0.01
# r = 0.02
# r = 0.03
# r = 0.04
# r = 0.05
# r = 0.06
# r = 0.07
# r = 0.08
# r = 0.09
# r = 0.1
# r = 0.11
# r = 0.12
# r = 0.13
# r = 0.14
# r = 0.15
# r = 0.16
# r = 0.17
# r = 0.18
# r = 0.19
# r = 0.2
# r = 0.21
# r = 0.22
# r = 0.23
# r = 0.24
# r = 0.25
# r = 0.26
# r = 0.27
# r = 0.28
# r = 0.29
# r = 0.3
# r = 0.31
# r = 0.32
# r = 0.33
# r = 0.34
# r = 0.35000000000000003
# r = 0.36
# r = 0.37
# r = 0.38

# %%
using Plots; gr()
# Out:
# Plots.GRBackend()

# %%
scatter(rs, num_V_data, m=:square, lab="numerical")
plot!(rs, exact_V_data, lab="exact")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip6100)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip6100)" points="
# 32.2221,375.813 580.315,375.813 580.315,11.811 32.2221,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="32" y="11" width="549" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip6102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   33.7593,375.813 33.7593,11.811
#   "/>
# <polyline clip-path="url(#clip6102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   173.508,375.813 173.508,11.811
#   "/>
# <polyline clip-path="url(#clip6102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   313.256,375.813 313.256,11.811
#   "/>
# <polyline clip-path="url(#clip6102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   453.004,375.813 453.004,11.811
#   "/>
# <polyline clip-path="url(#clip6102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.2221,365.512 580.315,365.512
#   "/>
# <polyline clip-path="url(#clip6102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.2221,283.822 580.315,283.822
#   "/>
# <polyline clip-path="url(#clip6102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.2221,202.133 580.315,202.133
#   "/>
# <polyline clip-path="url(#clip6102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.2221,120.444 580.315,120.444
#   "/>
# <polyline clip-path="url(#clip6102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.2221,38.7553 580.315,38.7553
#   "/>
# <polyline clip-path="url(#clip6100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip6100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,375.813 32.2221,11.811
#   "/>
# <polyline clip-path="url(#clip6100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   33.7593,375.813 33.7593,370.353
#   "/>
# <polyline clip-path="url(#clip6100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   173.508,375.813 173.508,370.353
#   "/>
# <polyline clip-path="url(#clip6100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   313.256,375.813 313.256,370.353
#   "/>
# <polyline clip-path="url(#clip6100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   453.004,375.813 453.004,370.353
#   "/>
# <polyline clip-path="url(#clip6100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,365.512 40.4435,365.512
#   "/>
# <polyline clip-path="url(#clip6100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,283.822 40.4435,283.822
#   "/>
# <polyline clip-path="url(#clip6100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,202.133 40.4435,202.133
#   "/>
# <polyline clip-path="url(#clip6100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,120.444 40.4435,120.444
#   "/>
# <polyline clip-path="url(#clip6100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,38.7553 40.4435,38.7553
#   "/>
# <g clip-path="url(#clip6100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 33.7593, 389.613)" x="33.7593" y="389.613">0.0</text>
# </g>
# <g clip-path="url(#clip6100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 173.508, 389.613)" x="173.508" y="389.613">0.1</text>
# </g>
# <g clip-path="url(#clip6100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 313.256, 389.613)" x="313.256" y="389.613">0.2</text>
# </g>
# <g clip-path="url(#clip6100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 453.004, 389.613)" x="453.004" y="389.613">0.3</text>
# </g>
# <g clip-path="url(#clip6100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 370.012)" x="26.2221" y="370.012">0.0</text>
# </g>
# <g clip-path="url(#clip6100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 288.322)" x="26.2221" y="288.322">0.5</text>
# </g>
# <g clip-path="url(#clip6100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 206.633)" x="26.2221" y="206.633">1.0</text>
# </g>
# <g clip-path="url(#clip6100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 124.944)" x="26.2221" y="124.944">1.5</text>
# </g>
# <g clip-path="url(#clip6100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 43.2553)" x="26.2221" y="43.2553">2.0</text>
# </g>
# <polygon clip-path="url(#clip6102)" style="fill:#000000; fill-opacity:1" points="
#   42.7342,17.1147 42.7342,27.1147 52.7342,27.1147 52.7342,17.1147 42.7342,17.1147
#   "/>
# <polygon clip-path="url(#clip6102)" style="fill:#009af9; fill-opacity:1" points="
#   43.7342,18.1147 43.7342,26.1147 51.7342,26.1147 51.7342,18.1147 43.7342,18.1147
#   "/>
# <polygon clip-path="url(#clip6102)" style="fill:#000000; fill-opacity:1" points="
#   56.709,40.6849 56.709,50.6849 66.709,50.6849 66.709,40.6849 56.709,40.6849
#   "/>
# <polygon clip-path="url(#clip6102)" style="fill:#009af9; fill-opacity:1" points="
#   57.709,41.6849 57.709,49.6849 65.709,49.6849 65.709,41.6849 57.709,41.6849
#   "/>
# <polygon clip-path="url(#clip6102)" style="fill:#000000; fill-opacity:1" points="
#   70.6838,63.5562 70.6838,73.5562 80.6838,73.5562 80.6838,63.5562 70.6838,63.5562
#   "/>
# <polygon clip-path="url(#clip6102)" style="fill:#009af9; fill-opacity:1" points="
#   71.6838,64.5562 71.6838,72.5562 79.6838,72.5562 79.6838,64.5562 71.6838,64.5562
#   "/>
# <polygon clip-path="url(#clip6102)" style="fill:#000000; fill-opacity:1" points="
#   84.6587,85.6857 84.6587,95.6857 94.6587,95.6857 94.6587,85.6857 84.6587,85.6857
#   "/>
# <polygon clip-path="url(#clip6102)" style="fill:#009af9; fill-opacity:1" points="
#   85.6587,86.6857 85.6587,94.6857 93.6587,94.6857 93.6587,86.6857 85.6587,86.6857
#   "/>
# <polygon clip-path="url(#clip6102)" style="fill:#000000; fill-opacity:1" points="
#   98.6335,107.196 98.6335,117.196 108.633,117.196 108.633,107.196 98.6335,107.196
#   "/>
# <polygon clip-path="url(#clip6102)" style="fill:#009af9; fill-opacity:1" points="
#   99.6335,108.196 99.6335,116.196 107.633,116.196 107.633,108.196 99.6335,108.196
#   "/>
# <polygon clip-path="url(#clip6102)" style="fill:#000000; fill-opacity:1" points="
#   112.608,127.681 112.608,137.681 122.608,137.681 122.608,127.681 112.608,127.681
#   "/>
# <polygon clip-path="url(#clip6102)" style="fill:#009af9; fill-opacity:1" points=

# %%
area_vert_hopp(a,b,r)=16*√(2)*b*(r-a)^2 
area_horiz_hopp(a,b,r)=16*√(2)*a*(r-b)^2
# Out:
# area_horiz_hopp (generic function with 1 method)

# %%
w, h = 1.5, 1.0

num_A_data = Float64[]
exact_A_data = Float64[]

rs = 0.01:0.01:rhmax
for r in rs
    
    @show r
    
    a = w/2 - r
    b = h/2 - r
    
    push!(num_A_data, MC_horiz_hop_area(a, b, r))
    push!(exact_A_data, area_horiz_hopp(a, b, r))
end
# Out:
# r = 0.01
# r = 0.02
# r = 0.03
# r = 0.04
# r = 0.05
# r = 0.06
# r = 0.07
# r = 0.08
# r = 0.09
# r = 0.1
# r = 0.11
# r = 0.12
# r = 0.13
# r = 0.14
# r = 0.15
# r = 0.16
# r = 0.17
# r = 0.18
# r = 0.19
# r = 0.2
# r = 0.21
# r = 0.22
# r = 0.23
# r = 0.24
# r = 0.25

# %%
plot(rs, num_A_data, m=:square, lab="numerical")
plot!(rs, exact_A_data/2, m=:square, lab="exact") #The formula in the other notebook accounts for its two sides.
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip6500)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip6500)" points="
# 32.2221,375.813 580.315,375.813 580.315,11.811 32.2221,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="32" y="11" width="549" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip6502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   133.912,375.813 133.912,11.811
#   "/>
# <polyline clip-path="url(#clip6502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   241.635,375.813 241.635,11.811
#   "/>
# <polyline clip-path="url(#clip6502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   349.358,375.813 349.358,11.811
#   "/>
# <polyline clip-path="url(#clip6502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   457.08,375.813 457.08,11.811
#   "/>
# <polyline clip-path="url(#clip6502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   564.803,375.813 564.803,11.811
#   "/>
# <polyline clip-path="url(#clip6502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.2221,365.511 580.315,365.511
#   "/>
# <polyline clip-path="url(#clip6502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.2221,276.499 580.315,276.499
#   "/>
# <polyline clip-path="url(#clip6502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.2221,187.487 580.315,187.487
#   "/>
# <polyline clip-path="url(#clip6502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.2221,98.4751 580.315,98.4751
#   "/>
# <polyline clip-path="url(#clip6500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip6500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,375.813 32.2221,11.811
#   "/>
# <polyline clip-path="url(#clip6500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   133.912,375.813 133.912,370.353
#   "/>
# <polyline clip-path="url(#clip6500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   241.635,375.813 241.635,370.353
#   "/>
# <polyline clip-path="url(#clip6500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   349.358,375.813 349.358,370.353
#   "/>
# <polyline clip-path="url(#clip6500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   457.08,375.813 457.08,370.353
#   "/>
# <polyline clip-path="url(#clip6500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   564.803,375.813 564.803,370.353
#   "/>
# <polyline clip-path="url(#clip6500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,365.511 40.4435,365.511
#   "/>
# <polyline clip-path="url(#clip6500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,276.499 40.4435,276.499
#   "/>
# <polyline clip-path="url(#clip6500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,187.487 40.4435,187.487
#   "/>
# <polyline clip-path="url(#clip6500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,98.4751 40.4435,98.4751
#   "/>
# <g clip-path="url(#clip6500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0,
#   "/>
# <polyline clip-path="url(#clip6900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,369.899 46.9343,369.899
#   "/>
# <polyline clip-path="url(#clip6900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,297.968 46.9343,297.968
#   "/>
# <polyline clip-path="url(#clip6900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,226.036 46.9343,226.036
#   "/>
# <polyline clip-path="url(#clip6900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,154.104 46.9343,154.104
#   "/>
# <polyline clip-path="url(#clip6900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.8117,82.1724 46.9343,82.1724
#   "/>
# <g clip-path="url(#clip6900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 139.279, 389.613)" x="139.279" y="389.613">0.05</text>
# </g>
# <g clip-path="url(#clip6900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 245.707, 389.613)" x="245.707" y="389.613">0.10</text>
# </g>
# <g clip-path="url(#clip6900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 352.134, 389.613)" x="352.134" y="389.613">0.15</text>
# </g>
# <g clip-path="url(#clip6900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 458.562, 389.613)" x="458.562" y="389.613">0.20</text>
# </g>
# <g clip-path="url(#clip6900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 564.989, 389.613)" x="564.989" y="389.613">0.25</text>
# </g>
# <g clip-path="url(#clip6900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 32.8117, 374.399)" x="32.8117" y="374.399">0.99</text>
# </g>
# <g clip-path="url(#clip6900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 32.8117, 302.468)" x="32.8117" y="302.468">1.00</text>
# </g>
# <g clip-path="url(#clip6900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 32.8117, 230.536)" x="32.8117" y="230.536">1.01</text>
# </g>
# <g clip-path="url(#clip6900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 32.8117, 158.604)" x="32.8117" y="158.604">1.02</text>
# </g>
# <g clip-path="url(#clip6900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 32.8117, 86.6724)" x="32.8117" y="86.6724">1.03</text>
# </g>
# <polyline clip-path="url(#clip6902)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.1373,290.149 75.4228,291.484 96.7083,234.564 117.994,234.149 139.279,188.213 160.565,259.084 181.85,295.894 203.136,202.884 224.421,268.759 245.707,272.376
#   266.992,182.497 288.278,205.89 309.563,289.6 330.849,301.988 352.134,316.239 373.42,289.223 394.705,241.168 415.991,181.08 437.276,365.511 458.562,156.781
#   479.847,344.618 501.133,22.113 522.418,176.609 543.704,68.1058
#   "/>
# <polygon clip-path="url(#clip6902)" style="fill:#000000; fill-opacity:1" points="
#   49.1373,285.149 49.1373,295.149 59.1373,295.149 59.1373,285.149 49.1373,285.149
#   "/>
# <polygon clip-path="url(#clip6902)" style="fill:#009af9; fill-opacity:1" points="
#   50.1373,286.149 50.1373,294.149 58.1373,294.149 58.1373,286.149 50.1373,286.149
#   "/>
# <polygon clip-path="url(#clip6902)" style="fill:#000000; fill-opacity:1" points="
#   70.4228,286.484 70.4228,296.484 80.4228,296.484 80.4228,286.484 70.4228,286.484
#   "/>
# <polygon clip-path="url(#clip6902)" style="fill:#009af9; fill-opacity:1" points="
#   71.4228,287.484 71.4228,295.484 79.4228,295.484 79.4228,287.484 71.4228,287.484
#   "/>
# <polygon clip-path="url(#clip6902)" style="fill:#000000; fill-opacity:1" points="
#   91.7083,229.564 91.7083,239.564 101.708,239.564 101.708,229.564 91.7083,229.564
#   "/>
# <polygon clip-path="url

# %%
area_col_free(a,b,r)=(16*π*a*b*r-32*(a+b)*r^2+16*r^3)*√(2) 
exprcircular_col(a,b,r,θ)=16*√2*(2*a*b*r*θ + 2*r^2*(a*cos(θ)-b*sin(θ)) + r^3*sin(θ)^2 )

function area_col(a,b,r)
    if (r<rhmax)
        result=area_col_free(a,b,r)
    elseif (rhmax<=r) && (r<rvmax)
     #   println(b, " ", r, " ", b/r)
        α=asin(b/r)
        result=exprcircular_col(a,b,r,α)-exprcircular_col(a,b,r,0)
    else
        α=asin(b/r)
        β=acos(a/r)        
        result=exprcircular_col(a,b,r,α)-exprcircular_col(a,b,r,β)   
    end
  #  print(" acol= ",result,  " \n ")
    return result
end
# Out:
# area_col (generic function with 1 method)

# %%
w, h = 1.5, 1.0

num_C_data = Float64[]
exact_C_data = Float64[]

rs = 0.01:0.01:rmax
for r in rs
    
    @show r
    
    a = w/2 - r
    b = h/2 - r
    
    push!(num_C_data, MC_collition_area(a,b,r))
    push!(exact_C_data, area_col(a, b, r))
end
# Out:
# r = 0.01
# r = 0.02
# r = 0.03
# r = 0.04
# r = 0.05
# r = 0.06
# r = 0.07
# r = 0.08
# r = 0.09
# r = 0.1
# r = 0.11
# r = 0.12
# r = 0.13
# r = 0.14
# r = 0.15
# r = 0.16
# r = 0.17
# r = 0.18
# r = 0.19
# r = 0.2
# r = 0.21
# r = 0.22
# r = 0.23
# r = 0.24
# r = 0.25
# r = 0.26
# r = 0.27
# r = 0.28
# r = 0.29
# r = 0.3
# r = 0.31
# r = 0.32
# r = 0.33
# r = 0.34
# r = 0.35000000000000003
# r = 0.36
# r = 0.37
# r = 0.38

# %%
plot(rs, num_C_data, m=:square, lab="numerical")
plot!(rs, exact_C_data, m=:square, lab="exact")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7500)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7500)" points="
# 32.2221,375.813 580.315,375.813 580.315,11.811 32.2221,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="32" y="11" width="549" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   33.7593,375.813 33.7593,11.811
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   173.508,375.813 173.508,11.811
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   313.256,375.813 313.256,11.811
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   453.004,375.813 453.004,11.811
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.2221,365.515 580.315,365.515
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.2221,294.346 580.315,294.346
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.2221,223.177 580.315,223.177
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.2221,152.008 580.315,152.008
#   "/>
# <polyline clip-path="url(#clip7502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.2221,80.839 580.315,80.839
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,375.813 32.2221,11.811
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   33.7593,375.813 33.7593,370.353
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   173.508,375.813 173.508,370.353
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   313.256,375.813 313.256,370.353
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   453.004,375.813 453.004,370.353
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,365.515 40.4435,365.515
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,294.346 40.4435,294.346
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,223.177 40.4435,223.177
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,152.008 40.4435,152.008
#   "/>
# <polyline clip-path="url(#clip7500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.2221,80.839 40.4435,80.839
#   "/>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 33.7593, 389.613)" x="33.7593" y="389.613">0.0</text>
# </g>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 173.508, 389.613)" x="173.508" y="389.613">0.1</text>
# </g>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 313.256, 389.613)" x="313.256" y="389.613">0.2</text>
# </g>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 453.004, 389.613)" x="453.004" y="389.613">0.3</text>
# </g>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 370.015)" x="26.2221" y="370.015">0.0</text>
# </g>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 298.846)" x="26.2221" y="298.846">0.3</text>
# </g>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 227.677)" x="26.2221" y="227.677">0.6</text>
# </g>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 156.508)" x="26.2221" y="156.508">0.9</text>
# </g>
# <g clip-path="url(#clip7500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.2221, 85.339)" x="26.2221" y="85.339">1.2</text>
# </g>
# <polyline clip-path="url(#clip7502)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   47.7342,286.765 61.709,233.301 75.6838,185.653 89.6587,149.352 103.633,117.394 117.608,88.5316 131.583,59.7502 145.558,50.2829 159.533,34.6597 173.508,24.6122
#   187.482,23.0806 201.457,23.8694 215.432,22.113 229.407,35.5425 243.382,44.6293 257.357,55.2552 271.331,69.4759 285.306,91.5729 299.281,110.39 313.256,133.326
#   327.231,155.733 341.206,181.348 355.18,208.511 369.155,234.06 383.13,259.758 397.105,280.402 411.08,295.492 425.055,310.154 439.029,320.968 453.004,329.584
#   466.979,338.141 480.954,345.086 494.929,350.652 508.904,355.437 522.878,359.261 536.853,362.208 550.828,364.578 564.803,365.511
#   "/>
# <polygon clip-path="url(#clip7502)" style="fill:#000000; fill-opacity:1" points="
#   42.7342,281.765 42.7342,291.765 52.7342,291.765 52.7342,281.765 42.7342,281.765
#   "/>
# <polygon clip-path="url(#clip7502)" style="fill:#009af9; fill-opacity:1" points="
#   43.7342,282.765 43.7342,290.765 51.7342,290.765 51.7342,282.765 43.7342,282.765
#   "/>
# <polygon clip-path="url(#clip7502)" style="fill:#000000; fill-opacity:1" points="
#   56.709,228.301 56.709,238.301 66.709,238.301 66.709,228.301 56.709,228.301
#   "/>
# <polygon clip-path="url(#clip7502)" style="fill:#009af9; fill-opacity:1" points="
#   57.709,229.301 57.709,237.301 65.709,237.301 65.709,229.301 57.709,229.301
#   "/>
# <polygon clip-path="url(#clip7502)" style="fill:#000000; fill-opacity:1" points="
#   70.6838,180.653 70.6838,190.653 80.6838,190.653 80.6838,180.653 70.6838,180.653
#   "/>
# <polygon clip-path="url(#clip7502)" style="fill:#009af9; fill-opacity:1" points="
#   71.6838,181.653 71.6838,189.653 79.6838,189.653 79.6838,181.653 71.6838,181.653
#   "/>
# <polygon clip-path="url(#clip7502)" style="fill:#000000; fill-opacity:1" points="
#   84.6587,144.352 84.6587,154.352 94.6587,154.352 94.6587,144.352 84.6587,144.352
#   "/>
# <polygon clip-path="url(#clip7502)" s

# %%
area_wall_free(a,b,r)=8*a*b^2-4*π*b*r^2+16/3*r^3 #perfect but needs generalization

exprpos_wall(a,b,r)=8*a*b^2
exprcircular_wall(a,b,r,θ)=8*b*r^2*θ+16/3*r^3*(cos(θ)) #sector

# la parte del "upper triangle"
a_wall_uppt(a,b,r)=8/3*b^2*sqrt(r^2-b^2)
a_wall_lowt(a,b,r)=8/3*a^2*sqrt(r^2-a^2)

function area_wall(a,b,r)
    if (r<rhmax)
        result=area_wall_free(a,b,r)
    elseif (rhmax<=r) && (r<rvmax)
         α=asin(b/r)
         negativo=exprcircular_wall(a,b,r,α)-exprcircular_wall(a,b,r,0)+a_wall_uppt(a,b,r)
         result=(exprpos_wall(a,b,r)-negativo) # we delete the 2 factor accounting the volume spliting,
    else
        α=asin(b/r)
        β=acos(a/r)
        negativo=0 # (exprcircular_wall(a,b,r,α)-exprcircular_wall(a,b,r,β))+a_wall_uppt(a,b,r)+a_wall_lowt(a,b,r)
        result=(exprpos_wall(a,b,r)-negativo)# we delete the 4 factor accounting the volume spliting,
    end
    return result
end
# Out:
# area_wall (generic function with 1 method)

# %%
w, h = 1.5, 1.0

num_W_data = Float64[]
exact_W_data = Float64[]

rs = 0.01:0.005:rmax
for r in rs
    
    @show r
    
    a = w/2 - r
    b = h/2 - r
    
    push!(num_W_data, MC_wall_area(a,b,r))
    push!(exact_W_data, area_wall(a, b, r))
end
# Out:
# r = 0.01
# r = 0.015
# r = 0.02
# r = 0.025
# r = 0.03
# r = 0.035
# r = 0.04
# r = 0.045
# r = 0.05
# r = 0.055
# r = 0.06
# r = 0.065
# r = 0.07
# r = 0.075
# r = 0.08
# r = 0.085
# r = 0.09
# r = 0.095
# r = 0.1
# r = 0.105
# r = 0.11
# r = 0.115
# r = 0.12
# r = 0.125
# r = 0.13
# r = 0.135
# r = 0.14
# r = 0.145
# r = 0.15
# r = 0.155
# r = 0.16
# r = 0.165
# r = 0.17
# r = 0.17500000000000002
# r = 0.18
# r = 0.185
# r = 0.19
# r = 0.195
# r = 0.2
# r = 0.20500000000000002
# r = 0.21
# r = 0.215
# r = 0.22
# r = 0.225
# r = 0.23
# r = 0.23500000000000001
# r = 0.24
# r = 0.245
# r = 0.25
# r = 0.255
# r = 0.26
# r = 0.265
# r = 0.27
# r = 0.275
# r = 0.28
# r = 0.28500000000000003
# r = 0.29
# r = 0.295
# r = 0.3
# r = 0.305
# r = 0.31
# r = 0.315
# r = 0.32
# r = 0.325
# r = 0.33
# r = 0.335
# r = 0.34
# r = 0.34500000000000003
# r = 0.35000000000000003
# r = 0.355
# r = 0.36
# r = 0.365
# r = 0.37
# r = 0.375
# r = 0.38

# %%
plot(rs, num_W_data, m=:square, lab="numerical")
plot!(rs, exact_W_data, m=:square, lab="exact")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip